# %%
import numpy as np
height = 128
width = 256
nClasses = 3

seg_labels = np.zeros((height, width, nClasses))

# Assume seg_labels is already populated with segmentation scores or labels
# To visualize the segmentation for the first class
class_0_segmentation = seg_labels[:, :, 0]

# You can use matplotlib to visualize
import matplotlib.pyplot as plt

plt.imshow(class_0_segmentation, cmap='gray')
plt.title('Segmentation for Class 0')
plt.show()
